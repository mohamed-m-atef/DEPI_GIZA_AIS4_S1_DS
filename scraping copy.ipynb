# %%
# Web scraping
# pip install beautifulsoup4


from bs4 import BeautifulSoup

# %%
#read the file abd show the contents
#

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
with open('home.html','r') as html_file:
    content = html_file.read()
    soup = BeautifulSoup(content,'lxml')
    print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 with open('home.html','r') as html_file:
#       2     content = html_file.read()
#       3     soup = BeautifulSoup(content,'lxml')
#
# File d:\DEPI Data Scientist\DS\.venv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'home.html'

# %%
with open('home.html','r') as html_file:
    content = html_file.read()
    soup = BeautifulSoup(content,'lxml')
    print(soup.find('h5'))
# Out:
# <h5 class="card-title">Python for Beginners</h5>

# %%
with open('home.html','r') as html_file:
    content = html_file.read()
    soup = BeautifulSoup(content,'lxml')
    print(soup.find('h5'))
# Out:
# <h5 class="card-title">Python for Beginners</h5>

# %%
with open('home.html','r') as html_file:
    content = html_file.read()
    soup = BeautifulSoup(content,'lxml')
    print(soup.find_all('h5'))
# Out:
# [<h5 class="card-title">Python for Beginners</h5>, <h5 class="card-title">Python Web Development</h5>, <h5 class="card-title">Python Machine Learning</h5>]

# %%
with open('home.html','r') as html_file:
    content = html_file.read()
    soup = BeautifulSoup(content,'lxml')
    courses_html_tages= soup.find_all('h5')
    for course in courses_html_tages:
        print(course)
# Out:
# <h5 class="card-title">Python for Beginners</h5>
# <h5 class="card-title">Python Web Development</h5>
# <h5 class="card-title">Python Machine Learning</h5>

# %%
with open('home.html','r') as html_file:
    content = html_file.read()
    soup = BeautifulSoup(content,'lxml')
    courses_html_tages= soup.find_all('h5')
    for course in courses_html_tages:
        print(course.text)
# Out:
# Python for Beginners
# Python Web Development
# Python Machine Learning

# %%
with open('home.html','r') as html_file:
    content = html_file.read()
    soup = BeautifulSoup(content,'lxml')
    course_cards = soup.find_all('div', class_='card')
    for course in course_cards:
        print(course)
# Out:
# <div class="card">
# <div class="card-header bg-primary text-white">Python and Web Scraping</div>
# <div class="card-body">
# <h5 class="card-title">Python for Beginners</h5>
# <p class="card-text">Welcome to the DEPI DS Program. Start your journey with Python fundamentals!</p>
# <a class="btn btn-custom btn-block" href="#">Win $20</a>
# </div>
# </div>
# <div class="card">
# <div class="card-header bg-success text-white">Data Science</div>
# <div class="card-body">
# <h5 class="card-title">Python Web Development</h5>
# <p class="card-text">Already know Python? Learn how to build powerful web applications with it!</p>
# <a class="btn btn-custom btn-block" href="#">Win $30</a>
# </div>
# </div>
# <div class="card">
# <div class="card-header bg-danger text-white">Machine Learning</div>
# <div class="card-body">
# <h5 class="card-title">Python Machine Learning</h5>
# <p class="card-text">Dive into AI and ML. Master data modeling and prediction using Python!</p>
# ...

# %%
with open('home.html','r') as html_file:
    content = html_file.read()
    soup = BeautifulSoup(content,'lxml')
    course_cards = soup.find_all('div', class_='card')
    for course in course_cards:
        course_name = course.h5.text
        course_win = course.a.text
        print(course_name)
        print(course_win)
# Out:
# Python for Beginners
# Win $20
# Python Web Development
# Win $30
# Python Machine Learning
# Win $100

# %%
with open('home.html','r') as html_file:
    content = html_file.read()
    soup = BeautifulSoup(content,'lxml')
    course_cards = soup.find_all('div', class_='card')
    for course in course_cards:
        course_name = course.h5.text
        course_win = course.a.text.split()[-1]
        print(f"{course_name}  costs {course_win}")
# Out:
# Python for Beginners  costs $20
# Python Web Development  costs $30
# Python Machine Learning  costs $100

# %%
#pip install requests
# Status code 200 means:
# The server was contacted.

# The request was processed without problems.

# The data was retrieved successfully.
import requests
# https://www.timesjobs.com/
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation=')
print(html_text)
# Out:
# <Response [200]>

# %%
import requests
from bs4 import BeautifulSoup

html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation=')

soup = BeautifulSoup(html_text.text, 'lxml')  
jobs_cards = soup.find_all('li', class_='clearfix job-bx wht-shd-bx')

print(jobs_cards)
# Out:
# [<li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <div class="d-flex d-flex-l-r job-title__logo">
# <div class="d-flex d-flex-l-r">
# <span class="logo-container">
# <i class="default-company-logo"></i>
# </span>
# <div>
# <h2 class="heading-trun" title="Python Developer">
# <a href="https://www.timesjobs.com/job-detail/python-developer-seven-consultancy-hyderabad-secunderabad-0-to-3-yrs-jobid-ATqt92bFMIxzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70769810','rest  ,  python  ,  web developer  ,  storage  ,  software developer','Hyderabad/Secunderabad','0 - 3','IT Software : Software Products &amp; Services','1','' )" target="_blank">
# <strong class="blkclor">Python</strong> Developer</a> </h2>
# <div class="d-flex d-flex-align-item">
# <h3 class="joblist-comp-name">
# 		    SEVEN CONSULTANCY
#
# 		    </h3>
# <span class="sim-posted">
# <span>Posted today</span>
# </span>
# </div>
# </div>
# </div>
# </div>
# ...

# %%
import requests
from bs4 import BeautifulSoup

html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation=')

soup = BeautifulSoup(html_text.text, 'lxml')  
jobs = soup.find('li', class_='clearfix job-bx wht-shd-bx')

print(jobs)
# there only one job appear on h3
# Out:
# <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <div class="d-flex d-flex-l-r job-title__logo">
# <div class="d-flex d-flex-l-r">
# <span class="logo-container">
# <i class="default-company-logo"></i>
# </span>
# <div>
# <h2 class="heading-trun" title="Python Developer">
# <a href="https://www.timesjobs.com/job-detail/python-developer-synechron-bengaluru-bangalore-1-to-6-yrs-jobid-DjpyPDQw90lzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','71124277','python core programming    ,   data manipulation libraries    ,   database interaction    ,   web framework development    ,   multithreading concepts    ,  information technology  ,  software requirements  ,  sql  ,  database management  ,  shell scripting  ,  technical skills  ,  rest  ,  gtp  ,  django','Bengaluru / Bangalore','1 - 6','IT Software : Software Products &amp; Services','1','' )" target="_blank">
# <strong class="blkclor">Python</strong> Developer</a> </h2>
# ...

# %%
# joblist-comp-name
import requests
from bs4 import BeautifulSoup

html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation=')

soup = BeautifulSoup(html_text.text, 'lxml')  
jobs = soup.find('li', class_='clearfix job-bx wht-shd-bx')
company_name  =  jobs.find('h3', class_ = 'joblist-comp-name').text.replace(' ','')
skills = jobs.find('div', class_ ='srp-skills').text.replace(' ','')
published_date = jobs.find('span', class_ = 'sim-posted').span.text

print(f'''   
      Company Name : {company_name}
      Required Skills: {skills}
      ''' )

print("")
# Out:
#
#       Company Name :
# 		SEVENCONSULTANCY
#
#
#       Required Skills:
#
#
#
# 					rest
#
#
# 					python
#
#
# 					webdeveloper
#
#
# 					storage
#
#
# 					softwaredeveloper

# %%
import requests

url = "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation="
response = requests.get(url)

print(f"Status Code: {response.status_code}")
# Out:
# Status Code: 200

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.text, 'lxml')  #'html.parser'

#search for all jobs
jobs = soup.find_all('li', class_='clearfix job-bx wht-shd-bx')
print(f"Found {len(jobs)} jobs.")
# Out:
# Found 25 jobs.

# %%
import requests
from bs4 import BeautifulSoup

html_text = requests.get(
    'https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation=')

soup = BeautifulSoup(html_text.text, 'lxml')
jobs = soup.find_all('li', class_='clearfix job-bx wht-shd-bx')

for job in jobs:
    company_name = job.find('h3', class_='joblist-comp-name')
    skills = job.find('div', class_='srp-skills')
    published_date = job.find('span', class_='sim-posted')

    if company_name and skills and published_date:
        company_name = company_name.text.strip()
        skills = ', '.join(skills.text.strip() for skill in skills.text.strip().split())
        published_date = published_date.span.text.strip()

        print(f'''   
    Company Name     : {company_name}
    Published Date   : {published_date}
    Required Skills  : {skills}
        ''')
        print("="*50)
# Out:
#
#     Company Name     : SYNECHRON
#     Published Date   : Posted today
#     Required Skills  : python core programming
#
#
#    					data manipulation libraries
#
#
#    					database interaction
#
#
#    					web framework development
#
#
#    					multithreading concepts
#
#
#    					information technology
#
#
#    					software requirements
#
#
#    					sql
#
#
#    					database management
#
#
#    					shell scripting
#
#
#    					technical skills
#
#
#    					rest
#
#
#    					gtp
#
#
#    					django, python core programming
#
#
#    					data manipulation libraries
#
#
#    					database interaction
#
#
#    					web framework development
#
#
#    					multithreading concepts
#
#
#    					information technology
#
#
#    					software requirements
#
#
#    					sql
#
#
#    					database management
#
#
#    					shell scripting
#
#
#    					technical skills
#
#
#    					rest
#
#
#    					gtp
#
#
#    					django, python core programming
#
#
# ...

# %%
import requests
from bs4 import BeautifulSoup

html_text = requests.get(
    'https://wuzzuf.net/search/jobs?a=spbg&q=machine%20learning')

soup = BeautifulSoup(html_text.text, 'lxml')
jobs = soup.find_all('div', class_='css-pkv5jc')

for job in jobs:
    company_name = job.find('a', class_='css-17s97q8')
    keywords = job.find_all('a', class_='css-o171kl') + job.find_all('a', class_ = 'css-5x9pm1')
    for keyword in range(len(keywords)):
        keywords[keyword] = keywords[keyword].text
    published_date = job.find('div', class_='css-4c4ojb')
    Location = job.find('span', class_ = 'css-5wys0k')

    if company_name and keywords and published_date and Location:
        company_name = company_name.text.strip()
        Location = Location.text.strip()
        keywords = ', '.join(keywords)
        published_date = published_date.text.strip()

    print(f'''   
    Company Name     : {company_name}\b\b
    Location         : {Location}
    Published Date   : {published_date}
    keywords         : {keywords}

=======================================
    ''')
# Out:
#
#     Company Name     : No
#     Location         : None
#     Published Date   : None
#     keywords         : ['AI / Machine Learning Developer', 'Experienced', ' · IT/Software Development', 'Machine Learning Developer', 'Machine Learning', ' · AI', ' · Software Development']
#
# ...
#
#
#     Company Name     : No
#     Location         : None
#     Published Date   : None
#     keywords         : ['Senior Machine Learning', 'Experienced', ' · IT/Software Development', ' · Engineering - Other', 'Machine Learning', ' · Cloud Computing', ' · PyTorch', ' · Data Engineering']
#
# ...
#
#
#     Company Name     : No
#     Location         : None
#     Published Date   : None
#     keywords         : ['Data Science Instructor', 'Entry Level', ' · IT/Software Development', ' · Engineering - Telecom/Technology', ' · Training/Instructor', ' · Data Science', ' · Computer Science', ' · Computer Engineering', ' · Python', 'Machine Learning', 'Deep Learning', ' · Artificial Intelligence (AI)']
#
# ...
#
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
import csv
from time import sleep
from random import uniform


base_url = "https://wuzzuf.net/search/jobs"
query = "machine learning"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

# عدد الصفحات اللي هنجمع منها الوظائف
number_of_pages = 5  

# تجهيز ملف CSV لتخزين النتائج
with open("wuzzuf_jobs.csv", mode="w", newline='', encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Job Title", "Company", "Location", "Posted", "Skills / Qualifications"])

    # نلف على كل صفحة
    for page in range(number_of_pages):
        params = {
            "q": query,
            "start": page * 15  # كل صفحة في الموقع فيها 15 وظيفة تقريبًا
        }

        print(f"🔄 Fetching page {page + 1}...")
        response = requests.get(base_url, headers=headers, params=params)
        soup = BeautifulSoup(response.content, "html.parser")

        jobs = soup.find_all("div", {"class": "css-1gatmva"})

        for job in jobs:
            title_tag = job.find("h2", {"class": "css-m604qf"})
            company_tag = job.find("a", {"class": "css-17s97q8"})
            location_tag = job.find("span", {"class": "css-5wys0k"})
            time_tag = job.find("div", {"class": "css-do6t5g"})
            skills_tag = job.find("div", {"class": "css-y4udm8"})

            title = title_tag.text.strip() if title_tag else "N/A"
            company = company_tag.text.strip() if company_tag else "N/A"
            location = location_tag.text.strip() if location_tag else "N/A"
            posted = time_tag.text.strip() if time_tag else "N/A"
            skills = skills_tag.text.strip().replace("\n", ", ") if skills_tag else "N/A"

            writer.writerow([title, company, location, posted, skills])

            print(f"✅ {title} at {company} ({location})")

        # تأخير عشوائي بين الصفحات عشان نحاكي التصفح الطبيعي 
            sleep(uniform(1.5, 3.0))

            print("\n Scraping complete! Data saved in 'wuzzuf_jobs.csv'")
# Out:
# 🔄 Fetching page 1...
# 🔄 Fetching page 2...
# 🔄 Fetching page 3...
# 🔄 Fetching page 4...
# 🔄 Fetching page 5...

# %%
text = "He Love Egypt"

# %%
text.lower()
# Out:
# 'he love egypt'

# %%
# import spacy
import tkinter as tk
from tkinter import ttk

# Load spaCy model
# nlp = spacy.load('en_core_web_sm')

# Input sentence
# doc = "Elon flew to mars yesterday. He carried biryani masala with him"
# doc = nlp(sentence)

# Create Tkinter window
root = tk.Tk()
root.title("POS Tagging with spaCy")

# Create Treeview (table)
tree = ttk.Treeview(root, columns=("Token", "POS", "Description"), show="headings")
tree.heading("Token", text="Token")
tree.heading("POS", text="POS")
tree.heading("Description", text="Description")
tree.pack(fill="both", expand=True)

# Insert data into table
# for token in doc:
#     tree.insert("", "end", values=(token.text, token.pos_, spacy.explain(token.pos_)))

# Run the GUI
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk, scrolledtext, messagebox
import spacy
from spacy import displacy
import webbrowser
import tempfile
import os

# Load default model
nlp = spacy.load("en_core_web_sm")

def analyze_text():
    text = text_area.get("1.0", tk.END).strip()
    if not text:
        messagebox.showwarning("Warning", "Please enter some text.")
        return
    
    doc = nlp(text)
    
    # Clear old results
    for row in tree.get_children():
        tree.delete(row)
    
    # Insert entities into table
    if doc.ents:
        for ent in doc.ents:
            tree.insert("", "end", values=(ent.text, ent.label_, spacy.explain(ent.label_)))
    else:
        messagebox.showinfo("Result", "No entities found.")
    
    # Show displaCy visualization in browser
    html = displacy.render(doc, style="ent", jupyter=False)
    with tempfile.NamedTemporaryFile("w", delete=False, suffix=".html") as tmp:
        tmp.write(html)
        tmp_path = tmp.name
    webbrowser.open(f"file://{tmp_path}")

# --- Tkinter Window ---
root = tk.Tk()
root.title("spaCy Named Entity Recognition (NER)")

# Input area
tk.Label(root, text="Enter text for NER:").pack(anchor="w", padx=5, pady=5)
text_area = scrolledtext.ScrolledText(root, wrap=tk.WORD, width=60, height=6)
text_area.insert(tk.END, "Apple was founded by Steve Jobs in California in 1976.")
text_area.pack(padx=5, pady=5, fill="both")

# Analyze button
analyze_btn = tk.Button(root, text="Extract Entities", command=analyze_text)
analyze_btn.pack(pady=5)

# Table for entities
columns = ("Entity", "Label", "Description")
tree = ttk.Treeview(root, columns=columns, show="headings", height=8)
for col in columns:
    tree.heading(col, text=col)
    tree.column(col, width=150)
tree.pack(padx=5, pady=5, fill="both", expand=True)

# Run Tkinter loop
root.mainloop()

# %%
import requests
html_text = requests.get('https://www.example.com')
print(html_text.text)

# %%
import requests
 
url = 'https://www.timesjobs.com/job-search?keywords=python&location=&experience=&refreshed=true'
 
response = requests.get(url, verify=False)
print(response.status_code)
# Out:
# d:\DEPI Data Scientist\DS\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.timesjobs.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 200

# %%
html_text = requests.get('https://wuzzuf.net/search/jobs/?q=python&a=navbl')
soup = BeautifulSoup(html_text.text, 'lxml')
jobs_cards = soup.find_all('div', class_='css-ghe2tq e1v1l3u10')
print(jobs_cards)
# Out:
# [<div class="css-ghe2tq e1v1l3u10"><style data-emotion="css pkv5jc">.css-pkv5jc{position:relative;min-height:60px;}</style><div class="css-pkv5jc"><a href="https://wuzzuf.net/jobs/careers/Software House Solution-Egypt-89312" rel="noreferrer" target="_blank"><style data-emotion="css 1in28d3">.css-1in28d3{position:absolute;inset-inline-end:0;inset-block-start:0;width:60px;height:60px;object-fit:contain;object-position:center center;}</style><img alt="Jobs and Careers at Software House Solution  Egypt" class="css-1in28d3" height="90" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/199024488667697f56b592.jpeg?height=90&amp;width=90" style="opacity:0;transition:opacity 0.2s ease-in-out" width="90"/></a><style data-emotion="css lptxge">.css-lptxge{-webkit-padding-end:60px;padding-inline-end:60px;}</style><div class="css-lptxge"><style data-emotion="css 193uk2c">.css-193uk2c{font-size:16px;font-weight:600;font-style:normal;letter-spacing:-0.4px;line-height:24px;color:#
# ...

# %%
import csv
from time import sleep
from random import uniform
base_url = 'https://wuzzuf.net/search/jobs'
query = 'machine learning'
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}
number_of_pages = 5
with open('wuzzuf_jobs.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["job Title", "Company", "Location", "Posted", "Skills / Qualifications"])
    for page in range(number_of_pages):
        params = {
            'q': query,
            'start': page * 15
        }
        print(f'🔄 Fetching page {page + 1}...')
        response = requests.get(base_url, headers=headers, params=params)
        soup = BeautifulSoup(response.content, 'html.parser')
        jobs = soup.find_all('div', {'class': 'css-1gatmva'})
        for job in jobs:
            title_tag = job.find('h2', {'class': 'css-m604qf'})
            company_tag = job.find('a', {'class': 'css-17s97q8'})
            location_tag = job.find('span', {'class': 'css-5wys0k'})
            time_tag = job.find('div', {'class': 'css-do6t5g'})
            skills_tag = job.find('div', {'class': 'css-y4udm8'})
            title = title_tag.text.strip() if title_tag else 'N/A'
            company = company_tag.text.strip() if company_tag else 'N/A'
            location = location_tag.text.strip() if location_tag else 'N/A'
            posted = time_tag.text.strip() if time_tag else 'N/A'
            skills = skills_tag.text.strip().replace('\n', ', ') if skills_tag else 'N/A'
            writer.writerow([title, company, location, posted, skills])
            print(f'✅ {title} at {company} ({location})')
# Out:
# 🔄 Fetching page 1...
# 🔄 Fetching page 2...
# 🔄 Fetching page 3...
# 🔄 Fetching page 4...
# 🔄 Fetching page 5...
