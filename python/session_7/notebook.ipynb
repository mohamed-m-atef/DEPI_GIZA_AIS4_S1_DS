# %%
import os

# %%
#print(os.getcwd())

# %%
#print (os.path.abspath('.'))
#main current working directory

# %%
#print (os.path.dirname(os.path.abspath('.')))
#Directory name of the current working directory

# %%
#os.chandir('D:/DEPI Data Scientist/DS/DEPI_GIZA_AIS4_S1_DS/python/session_7')
#Changing the current working directory to the specified path

# %%
#myFile = open('hello.txt', 'r')

# %%
#print(myFile)
#print(myFile.name)
#print(myFile.mode)
#print(myFile.encoding)

# %%
#print(myFile.read())

# %%
#print(myFile.readlines())
#print(type(myFile.readlines(1)))

# %%
#for line in myFile:
    #print(line)
    #if line.startswith("07"):
        #break

# %%
#myFile.close()
#file.close()

# %%
myFile = open('obj.txt', 'w')

# %%
myFile.write("fuck\n")
# Out:
# 5

# %%
file = open('fun.txt', 'w')

# %%
file.write("mohamed\n" *1000)
# Out:
# 8000

# %%
myList = ["osama" , 'ahmed ', 'sayed']
file.writelines(myList)

# %%
file = open('fun.txt', 'a')

# %%
file.write("depi rwad masr\n")
# Out:
# 15
