# %%
base = "D:/DEPI Data Scientist/DS/DEPI_GIZA_AIS4_S1_DS/python/Session_5"

# %%
type(base)
# Out:
# str

# %%
import os
import sys

# %%
file= os.listdir(base)
print(file)
# Out:
# ['rem.txt', 'session.ipynb']

# %%
os.remove(base+'/rem.txt')

# %%
base_dir = "./tmp_dir"
file_name= "text_1.txt"
file_path = os.path.join(base_dir, file_name)
print(file_path)
# Out:
# ./tmp_dir\text_1.txt

# %%
directory = "./tmp_directory_test_again"
if not os.path.exists(directory):
    os.makedirs(directory)
else:
    print("The directory already exists",directory)
# Out:
# The directory already exists ./tmp_directory_test_again

# %%
path = "tmp_dic"
if not os.path.exists(path):
    os.mkdir(path)
for i in range(20):
    inner_path = os.path.join(path, f"dir_{i}")
    if not os.path.exists(inner_path):
        os.mkdir(inner_path)

# %%
from create_folder import create_folder
create_folder("my_new_folder")

# %%
with open("./tmp_dic/text_1.txt", "a+") as file:
    file.write("Hello, World!\n")
    file.seek(0)
    content = file.read()
    print(content)
# Out:
# Hello, World!

# %%
try:
    5/0
except :
    print("An error occurred:")
# Out:
# An error occurred:

# %%
try:
    x=10
    y=int(input())
    x/y
except ZeroDivisionError:
    print("Division by zero is not allowed.")
# Out:
# Division by zero is not allowed.

# %%
try:
    x=10
    y=int(input())
    x/y
except Exception as e:
    print("An error occurred:", e)
# Out:
# An error occurred: division by zero

# %%
class StudentInfo:
    """
    this class is used to read files
    """

    def __init__(self,student_name,student_id,age,Gpa,gender):
        self.student_name=student_name
        self.student_id=student_id
        self.age=age
        self.Gpa=Gpa
        self.gender=gender
    

    def student_info(self,):
        return f"Student Name: {self.student_name}"

# %%
s1 = StudentInfo("mo",154,20,3.9,"male")
s1.student_info()
# Out:
# 'Student Name: mo'

# %%
s1.student_name="ArithmeticError"
s1.student_name
# Out:
# 'ArithmeticError'

# %%
s1.student_info()
# Out:
# 'Student Name: Ahmed, ID: 12345, Age: 20, GPA: 3.9, Gender: Male'

# %%
class test:
    def info(self):
        print(self)

# %%
t1=test()
print(t1)
t1.info()

# %%
class calculator:

    def __init__(self,num1: int,num2 :int):
        self.num1=num1
        self.num2=num2
    def add(self):
        return self.num1 + self.num2
    def subtract(self):
        return self.num1 - self.num2
    def multiply(self):
        return self.num1 * self.num2
    def divide(self):
        if self.num2 == 0:
            return "Error: Division by zero is not allowed."
        return self.num1 / self.num2

# %%
c1 = calculator(10,5)
c1.add()
# Out:
# 15

# %%
x= "mohamed"
x.split()
# Out:
# ['mohamed']

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    
    @abstractmethod
    def move(self):
        pass
class Bird(Animal):
    def move(self):
        return "The bird flies."
class Cat(Animal):
    def move(self):
        return "The cat walks on four legs."

# %%
a = Bird()
a.move()
# Out:
# 'The bird flies.'
