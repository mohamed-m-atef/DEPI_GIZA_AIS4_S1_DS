# %%
import os
directory = "dir"
if not os.path.exists(directory):
    os.makedirs(directory)
    print(f"The directory '{directory}' has been created.")
else:
    print(f"The directory '{directory}' already exists.")
# Out:
# The directory 'dir' already exists.

# %%
def create_foleder(path):
    if not os.path.exists(path):
        os.makedirs(path)
        print(f"The directory '{path}' has been created.")
    else:
        print(f"The directory '{directory}' already exists.")

# %%
class Member:
    def __init__(self):
        print("Member initialized")

Member_One = Member()
Member_Two = Member()
Member_Three = Member()
# Out:
# Member initialized
# Member initialized
# Member initialized

# %%
class Member:
    def __init__(self , first_name ,middle ,last, gender):

        self.fname = first_name
        self.mname = middle
        self.lname = last
        self.gender = gender



    def full_name(self):
        return f"{self.fname} {self.mname} {self.lname}"
    
    def name_with_title(self):
        if self.gender =="male":
            return f"Hello Mr {self.fname} {self.lname}"
        elif self.gender == "female":
            return f"Hello Miss {self.fname} {self.lname}"
        else:
            return f"Hello {self.fname} {self.lname}"

Member_One = Member("osama", "mohamed", "ahmed","")
Member_Two = Member("ahmed" , "ali" , "hassan" ,"male")
Member_Three = Member("mona" , "sayed" , "ibrahim" , "female")


#print(Member_One.fname, Member_One.mname, Member_One.lname)
#print(Member_Two.fname, Member_Two.mname, Member_Two.lname)
#print(Member_Three.fname, Member_Three.mname, Member_Three.lname)

print(Member_One.full_name())
print(Member_One.name_with_title())
# Out:
# osama mohamed ahmed
# Hello osama ahmed
