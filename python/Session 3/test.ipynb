# %%
is_sunny =True
temp = 25
if is_sunny:
    print("It's sunny")
    if temp>20:
        print("the weather is warm")
    else:
        print("the weather is cool")
else:
    print("It's not sunny day")
# Out:
# It's sunny
# the weather is warm

# %%
grade = int(input("Enter the grade: "))
if grade<0 or grade>100:
    print("Not valid grade")
else:
    if grade<=100:
        grade ="A"
        print(grade)
    elif grade<=90:
        grade ="B"
        print(grade)
    elif grade<=70:
        grade ="C"
        print(grade)
# Out:
# A

# %%
for i in range(6):
    if i==3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
for i in range (6):
    if i ==4:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range (6):
    if i ==2:
        pass
    else:
        print(i)
# Out:
# 0
# 1
# 3
# 4
# 5

# %%
x=6
while x>0:
    print("puthon")
    x-=1
# Out:
# puthon
# puthon
# puthon
# puthon
# puthon
# puthon

# %%
format

# %%
def info_user(name ="admin",age= 20):
    """  
    param_1 : take the name from the user
    type param_1: str
    param_2 : take age from user
    type param_2 : int

    return : return string of the name and age
    type return : str
    
    """

    return f"my name is {name} and my age is {age}"

# %%
info_user()
# Out:
# 'my name is admin and my age is 20'

# %%
from user_into import info_user
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 from user_into import info_user
#
# ModuleNotFoundError: No module named 'user_into'

# %%
info_user(age= 40,name ="moh")
# Out:
# 'my name is moh and my age is 40'

# %%
def function_1(name ="amit",age =20):
    return f"my name is {name}, my age is {age}"
function_1("mohaemd", 20)
# Out:
# 'my name is mohaemd, my age is 20'

# %%
function_1()
# Out:
# 'my name is amit, my age is 20'

# %%
def function_2(*name):
    return name
    print(type(name))

function_2("mohamed","amit",2,3,True,False ,0,1, [1,5,7,"od"])
# Out:
# ('mohamed', 'amit', 2, 3, True, False, 0, 1, [1, 5, 7, 'od'])

# %%
def function_2(**name):
    return name
    print(type(name))

function_2(username = "Mohamedmahmoud" , password = 10211165 , email = "mohamed@gmail.com")
# Out:
# {'username': 'Mohamedmahmoud',
#  'password': 10211165,
#  'email': 'mohamed@gmail.com'}

# %%
result = lambda x: x+10
result(10)
print(type(result))
#lambda --> fast function , save time and memory
# Out:
# <class 'function'>

# %%
info_user
# Out:
# <function __main__.info_user(name='admin', age=20)>

# %%
function_name = lambda x: x+10
print(function_name(5))
print(type(function_name))
# Out:
# 15
# <function <lambda> at 0x00000236E61F62A0>

# %%
function_name = lambda x: x+10
print(function_name(5))
print((function_name))
# Out:
# 15
# <function <lambda> at 0x00000236E6272CA0>

# %%
function_3 = lambda x,y: x+y
print(function_3(5,10))
# Out:
# 15

# %%
def func(n):
    return lambda a :a*n
func2 = func(2)
print(func2(11))
# Out:
# 22
