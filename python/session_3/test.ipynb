# %%
list_one =[1,2,3,4,"Depi" , "Learning",True ,[1,2,3,"True"],["ml","dl","ds"]]

# %%
type(list_one)
print(type(list_one))
# Out:
# <class 'list'>

# %%
list_one[7]
# Out:
# [1, 2, 3, 'True']

# %%
list_one[1:4]
# Out:
# [2, 3, 4]

# %%
list_one[7][3]
# Out:
# 'True'

# %%
list_one[7][3]="DA"
list_one
# Out:
# [1, 2, 3, 4, 'Depi', 'Learning', True, [1, 2, 3, 'DA'], ['ml', 'dl', 'ds']]

# %%
name ="Mohamed"
print(type(name))
list_1=list(name)
type(list_1)
# Out:
# <class 'str'>
# list
