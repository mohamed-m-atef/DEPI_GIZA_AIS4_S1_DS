# %%
list_one =[1,2,3,4,"Depi" , "Learning",True ,[1,2,3,"True"],["ml","dl","ds"]]

# %%
type(list_one)
print(type(list_one))
# Out:
# <class 'list'>

# %%
list_one[7]
# Out:
# [1, 2, 3, 'True']

# %%
list_one[1:4]
# Out:
# [2, 3, 4]

# %%
list_one[7][3]
# Out:
# 'True'

# %%
list_one[7][3]="DA"
list_one
# Out:
# [1, 2, 3, 4, 'Depi', 'Learning', True, [1, 2, 3, 'DA'], ['ml', 'dl', 'ds']]

# %%
name ="Mohamed"
print(type(name))
list_1=list(name)
type(list_1)
# Out:
# <class 'str'>
# list

# %%
list_1 =[1,2,3]

# %%
list_1.append(4)

# %%
list_2=["depi","learning","python"]
list_3 = list_2.append("DS")
type(list_3)
# Out:
# NoneType

# %%
list_2.insert(2,"amit")

# %%
list_2
# Out:
# ['depi', 'learning', 'amit', 'python', 'DS']

# %%
list_1=[1,2,3]
list_2= [4,5,6]
list_1.extend(list_2)
list_1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list_1=["depi","lerning","depi","python","DS"]
list_1.remove("depi")
list_1
list_1.append("depi")
print(list_1)
list_1.pop()
list_1
# Out:
# ['lerning', 'depi', 'python', 'DS', 'depi']
# ['lerning', 'depi', 'python', 'DS']

# %%
list_1
list_1.pop()
list_1
# Out:
# ['lerning', 'depi', 'python']

# %%
x=5
del x

# %%
del list_1[0]

# %%
list_1
# Out:
# ['depi', 'python']

# %%
name = input("Enter your name: ")
print(type(name))
# Out:
# <class 'str'>

# %%
name =input("Enter your name: ")
id = input("Enter your id: ")
age = input("Enter your age: ")
print(f"my name is : {name} \nmy id is : {id}\n age : {age}") 
print(type(name))
print(type(id))
# Out:
# my name is : mohamed
# my id is : 255
#  age : 20
# <class 'str'>
# <class 'str'>

# %%
input_list =["amit","learning","depi"]
list = input("Enter del: ")
input_list.remove(list)
input_list
# Out:
# ['amit', 'learning']

# %%
my_list = [1,2,2,2,3,4,5]
my_list.count(2)
# Out:
# 3

# %%
my_list_2 =[10,58,62,48,99,60,20]
my_list_2.sort()
my_list_2
# Out:
# [10, 20, 48, 58, 60, 62, 99]

# %%
my_list_2.reverse()
my_list_2
# Out:
# [99, 62, 60, 58, 48, 20, 10]

# %%
my_tuple=(50,20,48,30,1,19)
type(my_tuple)
my_tuple
# Out:
# (50, 20, 48, 30, 1, 19)

# %%
color = {"red"}
type(color)
# Out:
# set

# %%
set_a = {1,2,3}
set_b = {3,4,5}
print(set_a.difference(set_b))
# Out:
# {1, 2}

# %%
dict_a = {"name":"amit","name":101,"age":25}
dict_a["name"]
# Out:
# 101

# %%
key_dict = [("a",1),("b",2),("c",3)]

# %%
key_dict
# Out:
# [('a', 1), ('b', 2), ('c', 3)]

# %%
dict(key_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
5//6
# Out:
# 0

# %%
5%3
# Out:
# 2

# %%
num_1 = float(input("Enter num 1: "))
num_2 = float(input("Enter num 2: "))
print("Addition:",num_1 + num_2)
print("sub:",num_1 - num_2)
print("multi:",num_1 * num_2)
print("division:",num_1 / num_2)
# Out:
# Addition: 40.0
# sub: 0.0
# multi: 400.0
# division: 1.0

# %%
a =300
b=33
if b>a:
    print("b is greater than a")
else:
    print("a is greater than b")
# Out:
# a is greater than b

# %%
x=20
result = "Even" if x%2==0 else "Odd"
result
# Out:
# 'Even'
