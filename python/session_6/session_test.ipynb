# %%
class A:

    def do_this(self):
        print("Doing this in A")
class B(A):
    pass
class C():
    def do_this(self):
        print("Doing this in C")
class D(B,C):
    pass

# %%
x=D()
x.do_this()
# Out:
# Doing this in A

# %%
class A:

    def do_this(self):
        print("Doing this in A")
class B(A):
    pass
class C():
    def do_this(self):
        print("Doing this in C")
class D(C,B):
    pass

# %%
x=D()
x.do_this()
# Out:
# Doing this in C
