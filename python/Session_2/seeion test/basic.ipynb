# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
print("hello world")
# Out:
# hello world

# %%
x="5" #this is new variable
type(x)
# Out:
# str

# %%
name="Atef"
age= 21
print("my name is Mohamed ",name)
# Out:
# my name is Mohamed  Atef

# %%
'my name is {0}, and my age is {1}'.format("Mohamed",27)
'my name is {1}, and my age is {0}'.format("Mohamed",27)
'my name is {}, and my age is {}'.format("Mohamed",27)
# Out:
# 'my name is Mohamed, and my age is 27'

# %%
f"my name is{name} , and my age is {age}"
# Out:
# 'my name isAtef , and my age is 21'

# %%
def get_info():
    return f"my name is{name} , and my age is {age}"

# %%
get_info()
# Out:
# 'my name isAtef , and my age is 21'

# %%
x=[1,2,3,4,4.1,"ami",True]
type(x)
# Out:
# list

# %%
name ="depi_ds"
name[5]
# Out:
# 'd'

# %%
print(name[-2:-6:1])

# %%
print(name.upper())
name.lower()
# Out:
# DEPI_DS
# 'depi_ds'

# %%
print("hello\nworld")
print("hello\tworld")
print("hello world: \"hello\" ")
print("hello\b\b")
# Out:
# hello
# world
# hello	world
# hello world: "hello"
# hel

# %%
print("""     """)
